# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('world_population - Master Sheet world_population.csv')
df.head()
# Out:
#   CCA3 Continent Country/Territory 2022 Population 2020 Population  \
# 0  AFG      Asia       Afghanistan      41,128,771      38,972,230
# 1  ALB    Europe           Albania       2,842,321       2,866,849
# 2  DZA    Africa           Algeria      44,903,225      43,451,666
# 3  ASM   Oceania    American Samoa          44,273          46,189
# 4  AND    Europe           Andorra          79,824          77,700
#
#   2015 Population 2010 Population 2000 Population 1990 Population  \
# 0      33,753,499      28,189,672      19,542,982      10,694,796
# 1       2,882,481       2,913,399       3,182,021       3,295,066
# 2      39,543,154      35,856,344      30,774,621      25,518,074
# 3          51,368          54,849          58,230          47,818
# 4          71,746          71,519          66,097          53,569
#
#   1980 Population 1970 Population Area (km²) Density (per km²) Growth Rate  \
# 0      12,486,631      10,752,971    652,230            63 km²        103%
# ...

# %%
dic_data={'km²':'',',':'','%':''}
df=df.replace(dic_data,regex=True)
df
# Out:
#     CCA3 Continent  Country/Territory 2022 Population 2020 Population  \
# 0    AFG      Asia        Afghanistan        41128771        38972230
# 1    ALB    Europe            Albania         2842321         2866849
# 2    DZA    Africa            Algeria        44903225        43451666
# 3    ASM   Oceania     American Samoa           44273           46189
# 4    AND    Europe            Andorra           79824           77700
# ..   ...       ...                ...             ...             ...
# 229  WLF   Oceania  Wallis and Futuna           11572           11655
# 230  ESH    Africa     Western Sahara          575986          556048
# 231  YEM      Asia              Yemen        33696614        32284046
# 232  ZMB    Africa             Zambia        20017675        18927715
# 233  ZWE    Africa           Zimbabwe        16320537        15669666
#
#     2015 Population 2010 Population 2000 Population 1990 Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CCA3                         234 non-null    object
#  1   Continent                    234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   2022 Population              234 non-null    object
#  4   2020 Population              234 non-null    object
#  5   2015 Population              234 non-null    object
#  6   2010 Population              234 non-null    object
#  7   2000 Population              234 non-null    object
#  8   1990 Population              234 non-null    object
#  9   1980 Population              234 non-null    object
#  10  1970 Population              234 non-null    object
#  11  Area (km²)                   234 non-null    object
#  12  Density (per km²)            234 non-null    object
# ...

# %%
# df['2022 Population'] = pd.to_numeric(df['2022 Population'], errors='coerce')
# df['2020 Population'] = pd.to_numeric(df['2020 Population'], errors='coerce')
# df['2015 Population'] = pd.to_numeric(df['2015 Population'], errors='coerce')
# df['2010 Population'] = pd.to_numeric(df['2010 Population'], errors='coerce')
# df['2000 Population'] = pd.to_numeric(df['2000 Population'], errors='coerce')
# df['1990 Population'] = pd.to_numeric(df['1990 Population'], errors='coerce')
# df['1980 Population'] = pd.to_numeric(df['1980 Population'], errors='coerce')
# df['1970 Population'] = pd.to_numeric(df['1970 Population'], errors='coerce')
# df['Area (km²)'] = pd.to_numeric(df['Area (km²)'], errors='coerce')
# df['Density (per km²)'] = pd.to_numeric(df['Density (per km²)'], errors='coerce')
# df['Growth Rate'] = pd.to_numeric(df['Growth Rate'], errors='coerce')
# df['World Population Percentage'] = pd.to_numeric(df['World Population Percentage'], errors='coerce')

# # The 'Unnamed: 15' column seems to have only one non-null value, so you might want to check its content before converting
# df['Unnamed: 15'] = pd.to_numeric(df['Unnamed: 15'], errors='coerce')

# # Check the updated data types
# print(df.dtypes)

# %%
columns_to_convert = ['2022 Population', '2020 Population', '2015 Population', '2010 Population',
                       '2000 Population', '1990 Population', '1980 Population', '1970 Population',
                       'Area (km²)', 'Density (per km²)', 'Growth Rate']

# Convert specified columns to float
df[columns_to_convert] = df[columns_to_convert].astype(float)
df
# Out:
#     CCA3 Continent  Country/Territory  2022 Population  2020 Population  \
# 0    AFG      Asia        Afghanistan       41128771.0       38972230.0
# 1    ALB    Europe            Albania        2842321.0        2866849.0
# 2    DZA    Africa            Algeria       44903225.0       43451666.0
# 3    ASM   Oceania     American Samoa          44273.0          46189.0
# 4    AND    Europe            Andorra          79824.0          77700.0
# ..   ...       ...                ...              ...              ...
# 229  WLF   Oceania  Wallis and Futuna          11572.0          11655.0
# 230  ESH    Africa     Western Sahara         575986.0         556048.0
# 231  YEM      Asia              Yemen       33696614.0       32284046.0
# 232  ZMB    Africa             Zambia       20017675.0       18927715.0
# 233  ZWE    Africa           Zimbabwe       16320537.0       15669666.0
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CCA3                         234 non-null    object
#  1   Continent                    234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   2022 Population              234 non-null    float64
#  4   2020 Population              234 non-null    float64
#  5   2015 Population              234 non-null    float64
#  6   2010 Population              234 non-null    float64
#  7   2000 Population              234 non-null    float64
#  8   1990 Population              234 non-null    float64
#  9   1980 Population              234 non-null    float64
#  10  1970 Population              234 non-null    float64
#  11  Area (km²)                   234 non-null    float64
# ...

# %%
pd.set_option('display.float_format',lambda x:'%.2f' % x)
df
# Out:
#     CCA3 Continent  Country/Territory  2022 Population  2020 Population  \
# 0    AFG      Asia        Afghanistan      41128771.00      38972230.00
# 1    ALB    Europe            Albania       2842321.00       2866849.00
# 2    DZA    Africa            Algeria      44903225.00      43451666.00
# 3    ASM   Oceania     American Samoa         44273.00         46189.00
# 4    AND    Europe            Andorra         79824.00         77700.00
# ..   ...       ...                ...              ...              ...
# 229  WLF   Oceania  Wallis and Futuna         11572.00         11655.00
# 230  ESH    Africa     Western Sahara        575986.00        556048.00
# 231  YEM      Asia              Yemen      33696614.00      32284046.00
# 232  ZMB    Africa             Zambia      20017675.00      18927715.00
# 233  ZWE    Africa           Zimbabwe      16320537.00      15669666.00
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# ...

# %%
df.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count           234.00           234.00           234.00           234.00
# mean       34074414.71      33501070.95      31729956.24      29845235.03
# std       136766424.80     135589876.92     130404992.75     124218487.63
# min             510.00           520.00           564.00           596.00
# 25%          419738.50        415284.50        404676.00        393149.00
# 50%         5559944.50       5493074.50       5307400.00       4942770.50
# 75%        22476504.75      21447979.50      19730853.75      19159567.50
# max      1425887337.00    1424929781.00    1393715448.00    1348191368.00
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count           234.00           234.00           234.00           234.00
# mean       26269468.82      22710220.79      18984616.97      15786908.81
# std       111698206.72      97832173.35      81785186.08      67795091.64
# ...

# %%
df.drop(columns=['Unnamed: 15'],inplace=True)

# %%
df.nunique()
# Out:
# CCA3                           234
# Continent                        6
# Country/Territory              233
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              171
# Growth Rate                      9
# World Population Percentage     70
# dtype: int64

# %%
sns.heatmap(df.corr(),annot=True)
plt.rcParams['figure.figsize']=(20,7)
plt.show()
# Out:
# /var/folders/2c/nbqfmkm92vlbj_lmtkcmytsh0000gp/T/ipykernel_3232/848522714.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['CCA3', 'Continent', 'Country/Territory', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df2=df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by="2022 Population",ascending=False)
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               42898125.80      52706684.56      64211271.54
# South America      13781939.71      17270643.29      21224743.93
# Africa              6411304.35       8448006.61      11195625.07
# North America       7885865.15       9207334.03      10531660.62
# Europe             13118479.82      13850543.18      14406415.94
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               74701792.08      84400826.54      89165003.64
# South America      24973877.29      28077017.86      29509599.71
# Africa             14367474.25      18512773.19      21071972.67
# North America      12151739.60      13568016.28      14259596.25
# Europe             14521868.46      14712278.68      14830712.16
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df3=df2.transpose()
df3
# Out:
# Continent              Asia  South America      Africa  North America  \
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
# 1980 Population 52706684.56    17270643.29  8448006.61     9207334.03
# 1990 Population 64211271.54    21224743.93 11195625.07    10531660.62
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
#
# Continent            Europe    Oceania
# 1970 Population 13118479.82  846968.26
# 1980 Population 13850543.18  996532.17
# 1990 Population 14406415.94 1162774.87
# 2000 Population 14521868.46 1357512.09
# 2010 Population 14712278.68 1613163.65
# 2015 Population 14830712.16 1756664.48
# 2020 Population 14915843.92 1910148.96
# ...

# %%
df3.plot()
# Out:
# <Axes: >

# %%
# indentifying outliers
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >
